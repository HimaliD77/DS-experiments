# %% [markdown]
# IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# UPLOAD DATASET

# %%
df1=pd.read_csv("wine.csv")
df1
# Out:
#      fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0      7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# 1      7.8;0.88;0;2.6;0.098;25;67;0.9968;3.2;0.68;9.8;5
# 2     7.8;0.76;0.04;2.3;0.092;15;54;0.997;3.26;0.65;...
# 3     11.2;0.28;0.56;1.9;0.075;17;60;0.998;3.16;0.58...
# 4      7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# ...                                                 ...
# 1594  6.2;0.6;0.08;2;0.09;32;44;0.9949;3.45;0.58;10.5;5
# 1595  5.9;0.55;0.1;2.2;0.062;39;51;0.99512;3.52;0.76...
# 1596  6.3;0.51;0.13;2.3;0.076;29;40;0.99574;3.42;0.7...
# 1597  5.9;0.645;0.12;2;0.075;32;44;0.99547;3.57;0.71...
# 1598  6;0.31;0.47;3.6;0.067;18;42;0.99549;3.39;0.66;...
#
# [1599 rows x 1 columns]

# %%
import pandas as pd

df1 = pd.read_csv("wine.csv", header=None)

df_cleaned = df1[df1.columns[0]].str.split(';', expand=True)

df_cleaned.columns = [
    "fixed acidity", "volatile acidity", "citric acid", "residual sugar",
    "chlorides", "free sulfur dioxide", "total sulfur dioxide", "density",
    "pH", "sulphates", "alcohol", "quality"
]

corrected_file_path = "wine.xlsx"
df_cleaned.to_excel(corrected_file_path, index=False)

print(f"Corrected dataset saved as {corrected_file_path}")
# Out:
# Corrected dataset saved as wine.xlsx
#                                                       0
# 0     fixed acidity;"volatile acidity";"citric acid"...
# 1      7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# 2      7.8;0.88;0;2.6;0.098;25;67;0.9968;3.2;0.68;9.8;5
# 3     7.8;0.76;0.04;2.3;0.092;15;54;0.997;3.26;0.65;...
# 4     11.2;0.28;0.56;1.9;0.075;17;60;0.998;3.16;0.58...
# ...                                                 ...
# 1595  6.2;0.6;0.08;2;0.09;32;44;0.9949;3.45;0.58;10.5;5
# 1596  5.9;0.55;0.1;2.2;0.062;39;51;0.99512;3.52;0.76...
# 1597  6.3;0.51;0.13;2.3;0.076;29;40;0.99574;3.42;0.7...
# 1598  5.9;0.645;0.12;2;0.075;32;44;0.99547;3.57;0.71...
# 1599  6;0.31;0.47;3.6;0.067;18;42;0.99549;3.39;0.66;...
#
# [1600 rows x 1 columns]

# %%
df=pd.read_excel("wine.xlsx")
df
# Out:
#       fixed acidity    volatile acidity    citric acid    residual sugar  \
# 0     fixed acidity  "volatile acidity"  "citric acid"  "residual sugar"
# 1               7.4                 0.7              0               1.9
# 2               7.8                0.88              0               2.6
# 3               7.8                0.76           0.04               2.3
# 4              11.2                0.28           0.56               1.9
# ...             ...                 ...            ...               ...
# 1595            6.2                 0.6           0.08                 2
# 1596            5.9                0.55            0.1               2.2
# 1597            6.3                0.51           0.13               2.3
# 1598            5.9               0.645           0.12                 2
# 1599              6                0.31           0.47               3.6
#
#         chlorides    free sulfur dioxide    total sulfur dioxide    density  \
# ...

# %% [markdown]
# UNDERSTAND THE DATASET

# %%
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1600 non-null   object
#  1   volatile acidity      1600 non-null   object
#  2   citric acid           1600 non-null   object
#  3   residual sugar        1600 non-null   object
#  4   chlorides             1600 non-null   object
#  5   free sulfur dioxide   1600 non-null   object
#  6   total sulfur dioxide  1600 non-null   object
#  7   density               1600 non-null   object
#  8   pH                    1600 non-null   object
#  9   sulphates             1600 non-null   object
#  10  alcohol               1600 non-null   object
#  11  quality               1600 non-null   object
# dtypes: object(12)
# memory usage: 150.1+ KB
#        fixed acidity volatile acidity citric acid residual sugar chlorides  \
# ...

# %% [markdown]
# FIND NULL VALUES

# %%
df1.isnull().sum()
# Out:
# 0    0
# dtype: int64

# %% [markdown]
# FIND DUPLICATE VALUES

# %%
df1.duplicated().sum()
# Out:
# 240

# %% [markdown]
# DROP DUPLICATE VALUES

# %%
df1.drop_duplicates(inplace=True)

# %% [markdown]
# CHECK IF THERE ARE ANY DUPLICATE VALUES LEFT

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# fixed acidity           int64
# volatile acidity        int64
# citric acid             int64
# residual sugar          int64
# chlorides               int64
# free sulfur dioxide     int64
# total sulfur dioxide    int64
# density                 int64
# pH                      int64
# sulphates               int64
# alcohol                 int64
# quality                 int64
# dtype: object

# %%
df.dtypes
# Out:
# fixed acidity           int64
# volatile acidity        int64
# citric acid             int64
# residual sugar          int64
# chlorides               int64
# free sulfur dioxide     int64
# total sulfur dioxide    int64
# density                 int64
# pH                      int64
# sulphates               int64
# alcohol                 int64
# quality                 int64
# dtype: object

# %% [markdown]
# ONE HOT ENCODING

# %%
categorical_columns = ['quality']

data_encoded = pd.get_dummies(df, columns=categorical_columns)

print("\nAfter One-Hot Encoding:")
print(data_encoded.head())

encoded_file_path = "wine_encoded.xlsx"
data_encoded.to_excel(encoded_file_path, index=False)

print(f"One-hot encoded dataset saved as {encoded_file_path}")
# Out:
# After One-Hot Encoding:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             96                 0            0               0          0
# 1             70                77            1              11         40
# 2             74               113            1              31         62
# 3             74                89            5              26         56
# 4             12                13           57              11         39
#
#    free sulfur dioxide  total sulfur dioxide  density  pH  sulphates  alcohol  \
# 0                    0                     0        0   0          0        0
# 1                    3                    75      343  64         19       57
# 2                   18                   109      272  33         31       63
# 3                    7                    95      288  39         28       63
# 4                    9                   102      355  29         21       63
#
# ...

# %% [markdown]
# NORMALIZE

# %%
scaler = MinMaxScaler()
normalized_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

print("\nAfter Normalization:")
print(normalized_df.head())
# Out:
# After Normalization:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       1.000000          0.000000       0.0000        0.000000   0.000000
# 1       0.729167          0.538462       0.0125        0.120879   0.261438
# 2       0.770833          0.790210       0.0125        0.340659   0.405229
# 3       0.770833          0.622378       0.0625        0.285714   0.366013
# 4       0.125000          0.090909       0.7125        0.120879   0.254902
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.000000              0.000000  0.000000  0.000000   0.000000
# 1             0.050000              0.520833  0.786697  0.719101   0.197917
# 2             0.300000              0.756944  0.623853  0.370787   0.322917
# 3             0.116667              0.659722  0.660550  0.438202   0.291667
# 4             0.150000              0.708333  0.814220  0.325843   0.218750
#
#     alcohol   quality
# ...

# %% [markdown]
# OUTLIER DETECTION

# %%
from scipy.stats import zscore

# %%
z_scores = np.abs(df.apply(zscore))
outliers = (z_scores > 3).sum()

# %%
print("\nOutlier Detection (Z-scores > 3):")
print(outliers)
# Out:
# Outlier Detection (Z-scores > 3):
# fixed acidity            0
# volatile acidity        14
# citric acid              0
# residual sugar          33
# chlorides               44
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       0
# sulphates               34
# alcohol                  0
# quality                 11
# dtype: int64

# %%
z_scores = df.apply(zscore)

outliers_zscore = (np.abs(z_scores) > 3).sum()
print("\nOutliers Detected Using Z-Score (per column):")
print(outliers_zscore)

Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = ((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).sum()
print("\nOutliers Detected Using IQR (per column):")
print(outliers_iqr)

plt.figure(figsize=(12, 6))
sns.boxplot(data=df, orient="h", palette="Set2")
plt.title("Boxplot for Outlier Detection")
plt.tight_layout()
plt.show()
# Out:
# Outliers Detected Using Z-Score (per column):
# fixed acidity            0
# volatile acidity        14
# citric acid              0
# residual sugar          33
# chlorides               44
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       0
# sulphates               34
# alcohol                  0
# quality                 11
# dtype: int64
#
# Outliers Detected Using IQR (per column):
# fixed acidity           262
# volatile acidity         38
# citric acid               0
# residual sugar           74
# chlorides               106
# free sulfur dioxide       0
# total sulfur dioxide     31
# density                   0
# pH                       26
# sulphates                58
# alcohol                   0
# quality                  29
# dtype: int64

# %% [markdown]
# REMOVE OUTLIERS

# %%
z_scores = df.apply(zscore)

data_cleaned_zscore = df[(np.abs(z_scores) <= 3).all(axis=1)]

print("\nDataset After Removing Outliers (Z-Score Method):")
print(data_cleaned_zscore.shape)

Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

data_cleaned_iqr = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]

print("\nDataset After Removing Outliers (IQR Method):")
print(data_cleaned_iqr.shape)

cleaned_file_path_zscore = "wine_cleaned_zscore.xlsx"
cleaned_file_path_iqr = "wine_cleaned_iqr.xlsx"

data_cleaned_zscore.to_excel(cleaned_file_path_zscore, index=False)
data_cleaned_iqr.to_excel(cleaned_file_path_iqr, index=False)

print(f"\nCleaned dataset (Z-Score) saved as {cleaned_file_path_zscore}")
print(f"Cleaned dataset (IQR) saved as {cleaned_file_path_iqr}")
# Out:
# Dataset After Removing Outliers (Z-Score Method):
# (1483, 12)
#
# Dataset After Removing Outliers (IQR Method):
# (1106, 12)
#
# Cleaned dataset (Z-Score) saved as wine_cleaned_zscore.xlsx
# Cleaned dataset (IQR) saved as wine_cleaned_iqr.xlsx

# %% [markdown]
# VISUALIZATION

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.countplot(x='quality', data=df, palette='Set2')
plt.title('Distribution of Wine Quality Scores')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='quality', y='alcohol', data=df, palette='Set3')
plt.title('Alcohol Content by Wine Quality')
plt.xlabel('Quality')
plt.ylabel('Alcohol')
plt.show()

sns.pairplot(df[['alcohol', 'quality', 'pH', 'sulphates']], hue='quality', palette='Set2')
plt.show()
# Out:
# <ipython-input-61-3e1fda5e5bfd>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='quality', data=df, palette='Set2')
# <ipython-input-61-3e1fda5e5bfd>:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality', y='alcohol', data=df, palette='Set3')

# %% [markdown]
# FORWARD FEATURE SELECTION

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.feature_selection import SequentialFeatureSelector
import pandas as pd

model = DecisionTreeRegressor(random_state=42)

sfs = SequentialFeatureSelector(model, n_features_to_select='auto', direction='forward', scoring='r2', cv=5)
X_selected = sfs.fit_transform(X, y)

selected_features = X.columns[sfs.get_support()]

print("Selected Features:", selected_features.tolist())
# Out:
# Selected Features: ['fixed acidity', 'volatile acidity', 'total sulfur dioxide', 'sulphates', 'alcohol']

# %%
import matplotlib.pyplot as plt

features = ['fixed acidity', 'volatile acidity', 'total sulfur dioxide', 'sulphates', 'alcohol']
values = df[features].mean()

plt.figure(figsize=(8, 8))
plt.pie(values, labels=features, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Features')
plt.axis('equal')
plt.show()
